# %%
import pandas as pd
import plotmethods as pl

# Read the CSV file into a pandas DataFrame
dataframe_allroutename = pd.read_csv('dataframe_allroutename.csv', delimiter=',', encoding='utf-8')
dataframe_allroutename.fillna('', inplace=True)

# %% [markdown]
# Plot every Map interaction points in the map.

# %%
pl.plot_mapinteraction_points(dataframe_allroutename)

# %% [markdown]
# Different Traffic density:

# %%
pl.plot_routes_traffic_density(dataframe_allroutename)

# %% [markdown]
# Different map type:

# %%
pl.plot_maptypes_routes(dataframe_allroutename)

# %% [markdown]
# Different start point

# %%
pl.plot_routes_start_point(dataframe_allroutename, 's')

# %% [markdown]
# Different routes

# %%
pl.plot_route_routename(dataframe_allroutename, 's_to_Horse', 2)

# %%
### do not delete
import plotly.express as px
import pandas as pd
import base64
from PIL import Image

# Assuming your dataset is stored in a CSV file named 'dataframe_allroutename.csv'
data = pd.read_csv('dataframe_allroutename.csv')

# Convert 'posX' and 'posZ' columns to numerical type
data['posX'] = pd.to_numeric(data['posX'], errors='coerce')
data['posZ'] = pd.to_numeric(data['posZ'], errors='coerce')

# Load your background image and get dimensions
with open("map_vector_v3_icons.png", "rb") as background_image:
    encoded_string = base64.b64encode(background_image.read()).decode('utf-8')
    img = Image.open(background_image)
    img_width, img_height = img.size

print(img_width)
print(img_height)

# Create a scatter plot with background image
# Create a scatter plot with background image
filtered_data = data[data['scenario'] == 1]  # Filter data for scenario 1
fig = px.scatter(filtered_data, x='posX', y='posZ', title='Position Scatter Plot')

# Add background image
fig.update_layout(images=[dict(
    source= f'data:image/ext;base64,{encoded_string}',
    xref="x",
    yref="y",
    x=-1349.39,
    y=-217.9444,
    sizex= 1555.5924,  # Set sizex to the width of the image
    sizey= 1437.8156,  # Set sizey to the height of the image
    sizing="stretch",
    opacity=0.5,
    layer="below")])

# Show the plot
fig.show()

fig.write_html("output_plot.html")

# %%
# with dash
import dash
from dash import dcc, html, Input, Output
import plotly.express as px
import pandas as pd
import base64
from PIL import Image

# Load dataset
data = pd.read_csv('dataframe_allroutename.csv')

# Convert 'posX' and 'posZ' columns to numerical type
data['posX'] = pd.to_numeric(data['posX'], errors='coerce')
data['posZ'] = pd.to_numeric(data['posZ'], errors='coerce')

# Load background image and get dimensions
with open("map_vector_v3_icons.png", "rb") as background_image:
    encoded_string = base64.b64encode(background_image.read()).decode('utf-8')
    img = Image.open(background_image)
    img_width, img_height = img.size

# Define dropdown options based on unique scenario numbers
dropdown_options = [{'label': str(scenario), 'value': scenario} for scenario in data['scenario'].unique()]







# Initialize the Dash app
app = dash.Dash(__name__)

# Define app layout
app.layout = html.Div([
    dcc.Dropdown(
        id='scenario-dropdown',
        options=dropdown_options,
        value=data['scenario'].iloc[0],  # Default value is the first scenario in the dataset
        style={'width': '50%'}
    ),
    dcc.Graph(id='position-scatter-plot')
])

# Define callback to update scatter plot based on selected scenario
@app.callback(
    Output('position-scatter-plot', 'figure'),
    [Input('scenario-dropdown', 'value')]
)
def update_scatter_plot(selected_scenario):
    # Map selected scenario to color
    # Dictionary mapping scenarios to colors
    scenario_colors = {1: '#008837', 2: '#a6dba0', 3: '#7b3294', 4: '#c2a5cf'}
 
    
    # Filter data based on selected scenario
    filtered_data = data[data['scenario'] == selected_scenario]
    
    # Create scatter plot with color mapping
    fig = px.scatter(filtered_data, x='posX', y='posZ', title='Position Scatter Plot', color='scenario',
                     color_discrete_map=scenario_colors)

    # Add background image
    fig.update_layout(images=[dict(
        source=f'data:image/ext;base64,{encoded_string}',
        xref="x", 
        yref="y",
        x=-1349.39,
        y=-217.9444,
        sizex=1555.5924,  # Set sizex to the width of the image
        sizey=1437.8156,  # Set sizey to the height of the image
        sizing="stretch",
        opacity=0.5,
        layer="below")])
    
    return fig



if __name__ == '__main__':
    app.run_server(debug=True, dev_tools_ui=False, dev_tools_props_check=False)

# %%
# without using dash
import pandas as pd
import base64
from PIL import Image
import plotly.express as px

# Assuming your dataset is stored in a CSV file named 'dataframe_allroutename.csv'
data = pd.read_csv('dataframe_allroutename.csv')

# Convert 'posX' and 'posZ' columns to numerical type
data['posX'] = pd.to_numeric(data['posX'], errors='coerce')
data['posZ'] = pd.to_numeric(data['posZ'], errors='coerce')

# Load your background image and get dimensions
with open("map_vector_v3_icons.png", "rb") as background_image:
    encoded_string = base64.b64encode(background_image.read()).decode('utf-8')
    img = Image.open(background_image)
    img_width, img_height = img.size

# Define the layout for the dropdown and initial scatter plot
layout = {
    'title': 'Position Scatter Plot',
    'images': [dict(
        source=f'data:image/ext;base64,{encoded_string}',
        xref="x",
        yref="y",
        x=-1349.39,
        y=-217.9444,
        sizex=img_width,
        sizey=img_height,
        sizing="stretch",
        opacity=0.5,
        layer="below")]
}

# Create a figure with a dropdown menu
fig = px.scatter(data, x='posX', y='posZ', **layout)


# Show the plot
fig.show()

# %%
### try only using plotly 
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import base64
from PIL import Image

# Assuming your dataset is stored in a CSV file named 'dataframe_allroutename.csv'
data = pd.read_csv('dataframe_allroutename.csv')

# Convert 'posX' and 'posZ' columns to numerical type
data['posX'] = pd.to_numeric(data['posX'], errors='coerce')
data['posZ'] = pd.to_numeric(data['posZ'], errors='coerce')

# Load your background image and get dimensions
with open("map_vector_v3_icons.png", "rb") as background_image:
    encoded_string = base64.b64encode(background_image.read()).decode('utf-8')
    img = Image.open(background_image)
    img_width, img_height = img.size

# Create a scatter plot with background image
fig = go.Figure()

# Add background image
fig.update_layout(images=[dict(
    source= f'data:image/ext;base64,{encoded_string}',
    xref="x",
    yref="y",
    x=-1349.39,
    y=-217.9444,
    sizex= 1555.5924,  # Set sizex to the width of the image
    sizey= 1437.8156,  # Set sizey to the height of the image
    sizing="stretch",
    opacity=0.5,
    layer="below")])


#################add trace
fig.add_trace(
    go.Scatter(x=data['posX'],
               y=data['posZ'],
               mode='markers',
               name="High"))

fig.write_html("output_plot.html")

# %%
## only using plotly express
import plotly.express as px
import pandas as pd
import base64
from PIL import Image

# Load your dataset
data = pd.read_csv('dataframe_allroutename.csv')

# Convert 'posX' and 'posZ' columns to numerical type
data['posX'] = pd.to_numeric(data['posX'], errors='coerce')
data['posZ'] = pd.to_numeric(data['posZ'], errors='coerce')

# Load your background image and get dimensions
with open("map_vector_v3_icons.png", "rb") as background_image:
    encoded_string = base64.b64encode(background_image.read()).decode('utf-8')
    img = Image.open(background_image)
    img_width, img_height = img.size

# Define dropdown options based on unique scenarios
dropdown_options = [{'label': f'Scenario {scenario}', 'value': scenario} for scenario in data['scenario'].unique()]

# Define a function to update the scatter plot based on selected scenario
def update_scatter_plot(selected_scenario):
    # Filter data based on selected scenario
    filtered_data = data[data['scenario'] == selected_scenario]
    
    # Create a scatter plot with background image
    fig = px.scatter(filtered_data, x='posX', y='posZ', title=f'Position Scatter Plot (Scenario {selected_scenario})')

    # Add background image
    fig.update_layout(images=[dict(
        source=f'data:image/ext;base64,{encoded_string}',
        xref="x",
        yref="y",
        x=-1349.39,
        y=-217.9444,
        sizex=img_width,  # Set sizex to the width of the image
        sizey=img_height,  # Set sizey to the height of the image
        sizing="stretch",
        opacity=0.5,
        layer="below")])

    # Show the plot
    fig.show()

# Create a dropdown menu
dropdown = dcc.Dropdown(
    id='scenario-dropdown',
    options=dropdown_options,
    value=data['scenario'].iloc[0],  # Default value is the first scenario in the dataset
    style={'width': '50%'}
)

# Display the dropdown menu
dropdown

# Call the update_scatter_plot function when the dropdown value changes
update_scatter_plot(data['scenario'].iloc[0])

fig.write_html("output_plot.html")

# %%
### using dash
import plotly.express as px
import pandas as pd
import base64
from PIL import Image
from dash import dcc, html, Input, Output
import dash

#_______________________________________data preparation
# Load your dataset
data = pd.read_csv('dataframe_allroutename.csv')
# Define a dictionary mapping scenario numbers to colors
scenario_type = {
    1: 'no_adaptive & low_traffic',
    2: 'adaptive & low_traffic',
    3: 'no_adaptive & high_traffic',
    4: 'adaptive & high_traffic'
}

# Add a new column 'scenario_type' based on the 'scenario' column
data['scenario_type'] = data['scenario'].map(scenario_type)

# Convert 'posX' and 'posZ' columns to numerical type
data['posX'] = pd.to_numeric(data['posX'], errors='coerce')
data['posZ'] = pd.to_numeric(data['posZ'], errors='coerce')

# Load your background image and get dimensions
with open("map_vector_v3_icons.png", "rb") as background_image:
    encoded_string = base64.b64encode(background_image.read()).decode('utf-8')
    img = Image.open(background_image)
    img_width, img_height = img.size

##_______________________________________create dash
app = dash.Dash(__name__)

# Define dropdown options based on unique scenarios
scenario_dropdown_options = [{'label': f'Scenario {scenario}', 'value': scenario} for scenario in data['scenario'].unique()]

# Define dropdown options based on unique start points
start_point_dropdown_options = [{'label': f'Start Point {point}', 'value': point} for point in data['start_point'].unique()]

# Remove null values from the 'routename' column
cleaned_data = data.dropna(subset=['routename'])

# Extract unique route names from the cleaned data
route_names = cleaned_data['routename'].unique()

# Define dropdown options based on unique route names
route_dropdown_options = [{'label': name, 'value': name} for name in route_names]


# Define app layout
app.layout = html.Div([
    dcc.Dropdown(
        id='scenario-dropdown',
        options=scenario_dropdown_options,
        value=data['scenario'].iloc[0],  # Default value is the first scenario in the dataset
        style={'width': '50%'},
        multi=True,
    ),
    dcc.Dropdown(
        id='start-point-dropdown',
        options=start_point_dropdown_options,
        value=data['start_point'].iloc[0],  # Default value is the first start point in the dataset
        style={'width': '50%'},
        multi=True,
    ),
    dcc.Dropdown(
        id='route-dropdown',
        options=route_dropdown_options,
        value=route_names[0],  # Default value is the first route name in the dataset
        style={'width': '50%'},
        multi=True,
    ),
    dcc.RadioItems(
        id='highlight-points',
        options=[
            {'label': 'Highlight map interaction points', 'value': 'highlight'},
            {'label': 'Do not highlight', 'value': 'none'}
        ],
        value='none',
        labelStyle={'display': 'block'}
    ),
    html.Div(dcc.Graph(
        id='output-graph',
        style={'height': '1300px'}  # Adjust height here
    )),
])

# Define callback to update the scatter plot based on selected scenario, start point, and route name
# Define callback to update the scatter plot based on selected scenario, start point, and route name
# Define callback to update the scatter plot based on selected scenario, start point, and route name
@app.callback(
    Output('output-graph', 'figure'),
    [Input('scenario-dropdown', 'value'),
     Input('start-point-dropdown', 'value'),
     Input('route-dropdown', 'value'),
     Input('highlight-points', 'value')]
)
def update_graph(selected_scenarios, selected_start_points, selected_routes, highlight):
    # Convert selected_scenarios to a list if it's not already
    if not isinstance(selected_scenarios, list):
        selected_scenarios = [selected_scenarios]

    # Convert selected_start_points to a list if it's not already
    if not isinstance(selected_start_points, list):
        selected_start_points = [selected_start_points]

    # Convert selected_routes to a list if it's not already
    if not isinstance(selected_routes, list):
        selected_routes = [selected_routes]

    # Filter data based on selected scenarios, start points, and route names
    filtered_data = data[
        (data['scenario'].isin(selected_scenarios)) &
        (data['start_point'].isin(selected_start_points)) &
        (data['routename'].isin(selected_routes))
    ]

    # Create a scatter plot with background image
    fig = px.scatter(filtered_data, x='posX', y='posZ', title='Position Scatter Plot', color='scenario_type')

    # Highlight map interaction points based on their phases
    if highlight == 'highlight':    
        # Update marker colors based on mapInteractions
        marker_colors = ['red' if pd.notna(interaction) and interaction != "NaN" else 'grey' for interaction in filtered_data['mapInteractions']]

        print(marker_colors)
        fig.update_traces(marker=dict(color=marker_colors))


    # Adjust the size of points
    fig.update_traces(marker=dict(size=4))

    # Add background image
    fig.update_layout(images=[dict(
        source=f'data:image/ext;base64,{encoded_string}',
        xref="x",
        yref="y",
        x=-1349.39,
        y=-217.9444,
        sizex=1510.5924,  # Set sizex to the width of the image
        sizey=1437.8156,  # Set sizey to the height of the image
        sizing="stretch",
        opacity=1,
        layer="below")])

    # Return the plot
    return fig


    


# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\xuzhengfang\AppData\Local\Temp\ipykernel_11168\3805427609.py:11: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('dataframe_allroutename.csv')
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
