# %% [markdown]
# # There are three method to plot the trajectory  1 byParticipant  2 byScenario  3 byPartipantUsing
# # byPartipantUsing only display points where has Human Map Interaction, and red points where has setNavigation and CheckedIn.
# # Users can change the parameters of method to get different results

# %%
import plotmethods as pl

pl.byParticipant(13)

pl.byScenario(1)
pl.byScenario(2)
pl.byScenario(3)
pl.byScenario(4)

pl.byPartipantUsing(13)
