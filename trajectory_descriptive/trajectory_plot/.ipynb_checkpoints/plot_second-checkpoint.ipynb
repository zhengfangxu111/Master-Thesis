# %%
import pandas as pd
import plotmethods as pl

# Read the CSV file into a pandas DataFrame
dataframe_allroutename = pd.read_csv('dataframe_allroutename.csv', delimiter=',', encoding='utf-8')
dataframe_allroutename.fillna('', inplace=True)
# Out:
# /var/folders/2_/52hq81kn1d37sbcw9s2jxtbr0000gn/T/ipykernel_59120/1212901269.py:5: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe_allroutename = pd.read_csv('dataframe_allroutename.csv', delimiter=',', encoding='utf-8')

# %% [markdown]
# Plot every Map interaction points in the map.

# %%
pl.plot_mapinteraction_points(dataframe_allroutename)

# %% [markdown]
# Different Traffic density:

# %%
pl.plot_routes_traffic_density(dataframe_allroutename)

# %% [markdown]
# Different map type:

# %%
pl.plot_maptypes_routes(dataframe_allroutename)

# %% [markdown]
# Different start point

# %%
pl.plot_routes_start_point(dataframe_allroutename, 'n')

# %% [markdown]
# Different routes

# %%
pl.plot_route_routename(dataframe_allroutename, 'e_to_Cafécity', 4)
# Out:
# /Users/monabartling/Documents/Arbeit/Projekte/FWF Schrödinger/Publications/CAVE study/cave_context_aware_mobile_maps/trajectory_plot/plotmethods.py:689: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['posX'] = pd.to_numeric(filtered_df['posX'], errors='coerce')
# /Users/monabartling/Documents/Arbeit/Projekte/FWF Schrödinger/Publications/CAVE study/cave_context_aware_mobile_maps/trajectory_plot/plotmethods.py:690: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
